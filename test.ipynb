# %%
import streamlit as st

# %%
# Titre de l'application
st.title("Ma première application Streamlit")
# Out:
# 2023-09-18 11:31:29.185
# ...
#   command:
#
#     streamlit run C:\Users\laura\AppData\Roaming\Python\Python311\site-packages\ipykernel_launcher.py [ARGUMENTS]
# DeltaGenerator()
